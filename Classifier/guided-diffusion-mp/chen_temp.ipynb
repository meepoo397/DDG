# %%
import os
os.environ['PATH'] += ':/home/ccchen/anaconda3//bin'

# %%
! OPENAI_LOGDIR=/mnt/large-disk/guidance-team/classifier_log/ torchrun --standalone --nproc-per-node 1 scripts/classifier_train.py --data_dir /mnt/large-disk/guidance-team/classifier_data/ --image_size 64 --classifier_attention_resolutions 32,16,8 --classifier_depth 2 --classifier_width 128 --classifier_pool attention --classifier_resblock_updown True --classifier_use_scale_shift_norm True --val_data_dir /mnt/large-disk/guidance-team/classifier_val_data/ --eval_interval 1000 --iterations 300000 --anneal_lr True --batch_size 256 --microbatch 32 --lr 3e-4 --save_interval 2500 --weight_decay 0.05 --log_interval 10 --resume_checkpoint /mnt/large-disk/guidance-team/classifier_log/model010000.pt

# %%
# !which python
# !which torchrun
