# %%
import os
os.environ['PATH'] += ':/home/temp0/anaconda3/envs/edm2/bin'

# %%
GPU="0"

# %%
! CUDA_VISIBLE_DEVICES={GPU} OPENAI_LOGDIR=/data/guidance-team-new/classifier_log_trained_by_train_noised_True \
PYTHONPATH=.:./guided_diffusion:./base torchrun \
--standalone --nproc-per-node 1 scripts/classifier_train.py \
--data_dir /data/guidance-team-new/Imagenet/train_latent --image_size 64 \
--classifier_attention_resolutions 32,16,8 --classifier_depth 4 --classifier_width 128 \
--classifier_pool attention --classifier_resblock_updown True --classifier_use_scale_shift_norm True \
--val_data_dir /data/guidance-team-new/Imagenet/val_latent --eval_interval 1000 --iterations 300000 \
--anneal_lr True --batch_size 512 --microbatch 128 --lr 3e-4 --save_interval 1000 --weight_decay 0.05 --log_interval 100 \
# --resume_checkpoint /data/guidance-team-new/classifier_log_trained_by_train_noised_True/model002600.pt

# %%
! CUDA_VISIBLE_DEVICES={GPU} OPENAI_LOGDIR=/data/guidance-team-new/classifier_log_trained_by_train_noised_True \
PYTHONPATH=.:./guided_diffusion:./base torchrun \
--standalone --nproc-per-node 1 scripts/classifier_train.py \
--data_dir /data/guidance-team-new/Imagenet/train_latent --image_size 64 \
--classifier_attention_resolutions 32,16,8 --classifier_depth 4 --classifier_width 128 \
--classifier_pool attention --classifier_resblock_updown True --classifier_use_scale_shift_norm True \
--val_data_dir /data/guidance-team-new/Imagenet/val_latent --eval_interval 2000 --iterations 300000 \
--anneal_lr True --batch_size 512 --microbatch 128 --lr 3e-4 --save_interval 2000 --weight_decay 0.05 --log_interval 1000 \
--alpha=0.5 \
--resume_checkpoint /data/guidance-team-new/classifier_log_trained_by_train_noised_True/model003000.pt

# %%
! CUDA_VISIBLE_DEVICES={GPU} OPENAI_LOGDIR=/data/guidance-team-new/classifier_log_trained_by_train_noised_True \
PYTHONPATH=.:./guided_diffusion:./base torchrun \
--standalone --nproc-per-node 1 scripts/classifier_train.py \
--data_dir /data/guidance-team-new/Imagenet/train_latent --image_size 64 \
--classifier_attention_resolutions 32,16,8 --classifier_depth 4 --classifier_width 128 \
--classifier_pool attention --classifier_resblock_updown True --classifier_use_scale_shift_norm True \
--val_data_dir /data/guidance-team-new/Imagenet/val_latent --eval_interval 2000 --iterations 300000 \
--anneal_lr True --batch_size 512 --microbatch 128 --lr 3e-4 --save_interval 2000 --weight_decay 0.05 --log_interval 1000 \
--alpha=0.8 \
--resume_checkpoint /data/guidance-team-new/classifier_log_trained_by_train_noised_True/model020000.pt

# %%
! CUDA_VISIBLE_DEVICES={GPU} OPENAI_LOGDIR=/data/guidance-team-new/classifier_log_trained_by_train_noised_True \
PYTHONPATH=.:./guided_diffusion:./base torchrun \
--standalone --nproc-per-node 1 scripts/classifier_train.py \
--data_dir /data/guidance-team-new/Imagenet/train_latent --image_size 64 \
--classifier_attention_resolutions 32,16,8 --classifier_depth 4 --classifier_width 128 \
--classifier_pool attention --classifier_resblock_updown True --classifier_use_scale_shift_norm True \
--val_data_dir /data/guidance-team-new/Imagenet/val_latent --eval_interval 2000 --iterations 300000 \
--anneal_lr True --batch_size 512 --microbatch 128 --lr 3e-4 --save_interval 2000 --weight_decay 0.05 --log_interval 100 \
--alpha=0.5 \
--resume_checkpoint /data/guidance-team-new/classifier_log_trained_by_train_noised_True/model020000.pt

# %%
# 改--weight_decay 0.05->0.03
! CUDA_VISIBLE_DEVICES={GPU} OPENAI_LOGDIR=/data/guidance-team-new/classifier_log_trained_by_train_noised_True \
PYTHONPATH=.:./guided_diffusion:./base torchrun \
--standalone --nproc-per-node 1 scripts/classifier_train.py \
--data_dir /data/guidance-team-new/Imagenet/train_latent --image_size 64 \
--classifier_attention_resolutions 32,16,8 --classifier_depth 4 --classifier_width 128 \
--classifier_pool attention --classifier_resblock_updown True --classifier_use_scale_shift_norm True \
--val_data_dir /data/guidance-team-new/Imagenet/val_latent --eval_interval 2000 --iterations 300000 \
--anneal_lr True --batch_size 512 --microbatch 128 --lr 3e-4 --save_interval 2000 --weight_decay 0.03 --log_interval 100 \
--alpha=0.5 \
--resume_checkpoint /data/guidance-team-new/classifier_log_trained_by_train_noised_True/model066000.pt

# %%
# 改--weight_decay 0.05->0.03
! CUDA_VISIBLE_DEVICES={GPU} OPENAI_LOGDIR=/data/guidance-team-new/classifier_log_trained_by_train_noised_True \
PYTHONPATH=.:./guided_diffusion:./base torchrun \
--standalone --nproc-per-node 1 scripts/classifier_train.py \
--data_dir /data/guidance-team-new/Imagenet/train_latent --image_size 64 \
--classifier_attention_resolutions 32,16,8 --classifier_depth 4 --classifier_width 128 \
--classifier_pool attention --classifier_resblock_updown True --classifier_use_scale_shift_norm True \
--val_data_dir /data/guidance-team-new/Imagenet/val_latent --eval_interval 2000 --iterations 300000 \
--anneal_lr True --batch_size 512 --microbatch 128 --lr 3e-4 --save_interval 2000 --weight_decay 0.03 --log_interval 100 \
--alpha=0.5 \
--resume_checkpoint /data/guidance-team-new/classifier_log_trained_by_train_noised_True/model094000.pt

# %%
# 改--weight_decay 0.05->0.03
! CUDA_VISIBLE_DEVICES={GPU} OPENAI_LOGDIR=/data/guidance-team-new/classifier_log_trained_by_train_noised_True \
PYTHONPATH=.:./guided_diffusion:./base torchrun \
--standalone --nproc-per-node 1 scripts/classifier_train.py \
--data_dir /data/guidance-team-new/Imagenet/train_latent --image_size 64 \
--classifier_attention_resolutions 32,16,8 --classifier_depth 4 --classifier_width 128 \
--classifier_pool attention --classifier_resblock_updown True --classifier_use_scale_shift_norm True \
--val_data_dir /data/guidance-team-new/Imagenet/val_latent --eval_interval 2000 --iterations 300000 \
--anneal_lr True --batch_size 512 --microbatch 128 --lr 3e-4 --save_interval 2000 --weight_decay 0.03 --log_interval 100 \
--alpha=0.1 \
--resume_checkpoint /data/guidance-team-new/classifier_log_trained_by_train_noised_True/model100000.pt

# %%
# 改--weight_decay 0.05->0.03
! CUDA_VISIBLE_DEVICES={GPU} OPENAI_LOGDIR=/data/guidance-team-new/classifier_log_trained_by_train_noised_True \
PYTHONPATH=.:./guided_diffusion:./base torchrun \
--standalone --nproc-per-node 1 scripts/classifier_train.py \
--data_dir /data/guidance-team-new/Imagenet/train_latent --image_size 64 \
--classifier_attention_resolutions 32,16,8 --classifier_depth 4 --classifier_width 128 \
--classifier_pool attention --classifier_resblock_updown True --classifier_use_scale_shift_norm True \
--val_data_dir /data/guidance-team-new/Imagenet/val_latent --eval_interval 2000 --iterations 300000 \
--anneal_lr True --batch_size 512 --microbatch 128 --lr 3e-4 --save_interval 2000 --weight_decay 0.03 --log_interval 100 \
--alpha=0.3 \
--uniform_prob=0.1 \
--resume_checkpoint /data/guidance-team-new/classifier_log_trained_by_train_noised_True/model120000.pt

# %%
# 改--weight_decay 0.05->0.03
! CUDA_VISIBLE_DEVICES={GPU} OPENAI_LOGDIR=/data/guidance-team-new/classifier_log_trained_by_train_noised_True \
PYTHONPATH=.:./guided_diffusion:./base torchrun \
--standalone --nproc-per-node 1 scripts/classifier_train.py \
--data_dir /data/guidance-team-new/Imagenet/train_latent --image_size 64 \
--classifier_attention_resolutions 32,16,8 --classifier_depth 4 --classifier_width 128 \
--classifier_pool attention --classifier_resblock_updown True --classifier_use_scale_shift_norm True \
--val_data_dir /data/guidance-team-new/Imagenet/val_latent --eval_interval 2000 --iterations 300000 \
--anneal_lr True --batch_size 512 --microbatch 128 --lr 3e-4 --save_interval 2000 --weight_decay 0.05 --log_interval 100 \
--alpha=0.3 \
--uniform_prob=0.1 \
--resume_checkpoint /data/guidance-team-new/classifier_log_trained_by_train_noised_True/model122000.pt

# %%
# 改--weight_decay 0.05->0.03
! CUDA_VISIBLE_DEVICES={GPU} OPENAI_LOGDIR=/data/guidance-team-new/classifier_log_trained_by_train_noised_True \
PYTHONPATH=.:./guided_diffusion:./base torchrun \
--standalone --nproc-per-node 1 scripts/classifier_train.py \
--data_dir /data/guidance-team-new/Imagenet/train_latent --image_size 64 \
--classifier_attention_resolutions 32,16,8 --classifier_depth 4 --classifier_width 128 \
--classifier_pool attention --classifier_resblock_updown True --classifier_use_scale_shift_norm True \
--val_data_dir /data/guidance-team-new/Imagenet/val_latent --eval_interval 2000 --iterations 300000 \
--anneal_lr True --batch_size 512 --microbatch 128 --lr 3e-4 --save_interval 2000 --weight_decay 0.05 --log_interval 100 \
--alpha=0.1 \
--uniform_prob=0.1 \
--resume_checkpoint /data/guidance-team-new/classifier_log_trained_by_train_noised_True/model134000.pt

# %%
# 改--weight_decay 0.05->0.03
! CUDA_VISIBLE_DEVICES={GPU} OPENAI_LOGDIR=/data/guidance-team-new/classifier_log_trained_by_train_noised_True \
PYTHONPATH=.:./guided_diffusion:./base torchrun \
--standalone --nproc-per-node 1 scripts/classifier_train.py \
--data_dir /data/guidance-team-new/Imagenet/train_latent --image_size 64 \
--classifier_attention_resolutions 32,16,8 --classifier_depth 4 --classifier_width 128 \
--classifier_pool attention --classifier_resblock_updown True --classifier_use_scale_shift_norm True \
--val_data_dir /data/guidance-team-new/Imagenet/val_latent --eval_interval 2000 --iterations 300000 \
--anneal_lr True --batch_size 512 --microbatch 128 --lr 3e-4 --save_interval 2000 --weight_decay 0.03 --log_interval 100 \
--alpha=0.1 \
--uniform_prob=0.1 \
--resume_checkpoint /data/guidance-team-new/classifier_log_trained_by_train_noised_True/model158000.pt

# %%
# 改--weight_decay 0.05->0.03
! CUDA_VISIBLE_DEVICES={GPU} OPENAI_LOGDIR=/data/guidance-team-new/classifier_log_trained_by_train_noised_True \
PYTHONPATH=.:./guided_diffusion:./base torchrun \
--standalone --nproc-per-node 1 scripts/classifier_train.py \
--data_dir /data/guidance-team-new/Imagenet/train_latent --image_size 64 \
--classifier_attention_resolutions 32,16,8 --classifier_depth 4 --classifier_width 128 \
--classifier_pool attention --classifier_resblock_updown True --classifier_use_scale_shift_norm True \
--val_data_dir /data/guidance-team-new/Imagenet/val_latent --eval_interval 2000 --iterations 300000 \
--anneal_lr True --batch_size 512 --microbatch 128 --lr 3e-4 --save_interval 2000 --weight_decay 0.05 --log_interval 100 \
--alpha=0.05 \
--uniform_prob=0.1 \
--resume_checkpoint /data/guidance-team-new/classifier_log_trained_by_train_noised_True/model180000.pt

# %%
# 改--weight_decay 0.05->0.03
! CUDA_VISIBLE_DEVICES={GPU} OPENAI_LOGDIR=/data/guidance-team-new/classifier_log_trained_by_train_pure_first \
PYTHONPATH=.:./guided_diffusion:./base torchrun \
--standalone --nproc-per-node 1 scripts/classifier_train.py \
--data_dir /data/guidance-team-new/Imagenet/train_latent --image_size 64 \
--classifier_attention_resolutions 32,16,8 --classifier_depth 2 --classifier_width 128 \
--classifier_pool attention --classifier_resblock_updown True --classifier_use_scale_shift_norm True \
--val_data_dir /data/guidance-team-new/Imagenet/val_latent --eval_interval 200 --iterations 300000 \
--anneal_lr True --batch_size 512 --microbatch 128 --lr 3e-4 --save_interval 200 --weight_decay 0.03 --log_interval 100 \
--alpha=0.05 \
--uniform_prob=0.1 \
--noised=False
# --resume_checkpoint /data/guidance-team-new/classifier_log_trained_by_train_pure_first/model004300.pt

# %%
# 改--weight_decay 0.05->0.03
! CUDA_VISIBLE_DEVICES={GPU} OPENAI_LOGDIR=/data/guidance-team-new/classifier_log_trained_by_train_pure_first \
PYTHONPATH=.:./guided_diffusion:./base torchrun \
--standalone --nproc-per-node 1 scripts/classifier_train.py \
--data_dir /data/guidance-team-new/Imagenet/train_latent --image_size 64 \
--classifier_attention_resolutions 32,16,8 --classifier_depth 2 --classifier_width 128 \
--classifier_pool attention --classifier_resblock_updown True --classifier_use_scale_shift_norm True \
--val_data_dir /data/guidance-team-new/Imagenet/val_latent --eval_interval 200 --iterations 300000 \
--anneal_lr True --batch_size 512 --microbatch 128 --lr 3e-4 --save_interval 200 --weight_decay 0.03 --log_interval 100 \
--alpha=0.05 \
--uniform_prob=0.1 \
--noised=False \
--resume_checkpoint /data/guidance-team-new/classifier_log_trained_by_train_pure_first/model017400.pt

# %%
# 改--weight_decay 0.05->0.03
! CUDA_VISIBLE_DEVICES={GPU} OPENAI_LOGDIR=/data/guidance-team-new/classifier_log_trained_by_train_pure_first \
PYTHONPATH=.:./guided_diffusion:./base torchrun \
--standalone --nproc-per-node 1 scripts/classifier_train.py \
--data_dir /data/guidance-team-new/Imagenet/train_latent --image_size 64 \
--classifier_attention_resolutions 32,16,8 --classifier_depth 2 --classifier_width 128 \
--classifier_pool attention --classifier_resblock_updown True --classifier_use_scale_shift_norm True \
--val_data_dir /data/guidance-team-new/Imagenet/val_latent --eval_interval 200 --iterations 300000 \
--anneal_lr True --batch_size 512 --microbatch 128 --lr 3e-4 --save_interval 200 --weight_decay 0.03 --log_interval 100 \
--alpha=0.05 \
--uniform_prob=0.01 \
--noised=True \
--resume_checkpoint /data/guidance-team-new/classifier_log_trained_by_train_pure_first/model072000.pt

# %%
# 改--weight_decay 0.05->0.03
! CUDA_VISIBLE_DEVICES={GPU} OPENAI_LOGDIR=/data/guidance-team-new/classifier_log_trained_by_train_pure_first \
PYTHONPATH=.:./guided_diffusion:./base torchrun \
--standalone --nproc-per-node 1 scripts/classifier_train.py \
--data_dir /data/guidance-team-new/Imagenet/train_latent --image_size 64 \
--classifier_attention_resolutions 32,16,8 --classifier_depth 2 --classifier_width 128 \
--classifier_pool attention --classifier_resblock_updown True --classifier_use_scale_shift_norm True \
--val_data_dir /data/guidance-team-new/Imagenet/val_latent --eval_interval 200 --iterations 300000 \
--anneal_lr True --batch_size 512 --microbatch 128 --lr 3e-4 --save_interval 200 --weight_decay 0.03 --log_interval 100 \
--alpha=0.05 \
--uniform_prob=0.01 \
--noised=True \
--resume_checkpoint /data/guidance-team-new/classifier_log_trained_by_train_pure_first/model073800.pt

# %%
# 改--weight_decay 0.05->0.03
! CUDA_VISIBLE_DEVICES={GPU} OPENAI_LOGDIR=/data/guidance-team-new/classifier_log_trained_by_train_pure_first \
PYTHONPATH=.:./guided_diffusion:./base torchrun \
--standalone --nproc-per-node 1 scripts/classifier_train.py \
--data_dir /data/guidance-team-new/Imagenet/train_latent --image_size 64 \
--classifier_attention_resolutions 32,16,8 --classifier_depth 2 --classifier_width 128 \
--classifier_pool attention --classifier_resblock_updown True --classifier_use_scale_shift_norm True \
--val_data_dir /data/guidance-team-new/Imagenet/val_latent --eval_interval 200 --iterations 300000 \
--anneal_lr True --batch_size 512 --microbatch 128 --lr 3e-4 --save_interval 200 --weight_decay 0.03 --log_interval 100 \
--alpha=0.2 \
--uniform_prob=0.5 \
--noised=True \
--resume_checkpoint /data/guidance-team-new/classifier_log_trained_by_train_pure_first/model079600.pt
